# %% [markdown]
# # MODEL 1
# This notebook shows the implementation of the model 1. See the documenation for further details.
# #### The preprocessing we apply is the simple one;
# #### The dataset considered is just the article3 (train+test20);
# #### The Doc2vec model is trained on 9-folds of the dataset (train+test20);
# #### The SVM is trained by applying a 10-fold cross-validation which means we trained the SMV on  9-folds of the dataset (train+test20) and tested on the remaining 1-fold.

# %%
import os
import sys
import shutil
import random
import re
import regex
import string
from random import shuffle
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import KFold
from gensim import models
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn import svm, metrics
import matplotlib.pyplot as plt
from nltk.stem import PorterStemmer
from sklearn.preprocessing import normalize
from module_preprocessing import apply_preprocessing_simple
from ast import literal_eval

random_seed = [1234, 232345, 334456, 454567, 567448, 67839, 9822276, 763454, 644543, 3454421]

# %%
dataframe = pd.read_csv("crystal_ball_data/TT20_simple_rd/simple/Article03.csv", index_col='index')
dataframe.raw_text = dataframe.raw_text.apply(literal_eval)

dataframe.shape
# Out:
# (709, 2)

# %%
def create_vector_dataset(df, model,df_vector=pd.DataFrame()):
    '''
     This function creates a well structured dataset, which consists of n columns: n features and the tag.
     It transforms strings to vectors through the model Doc2Vec.
     which consists of n columns: n features and the tag. 
      Args:
         df (DataFrame): an semi-structured dataframe, look at create_raw_dataset.  
         model (Doc2Vec) : a trained Doc2Vec model.
         df_vector (DataFrame): an initialized dataframe with shape (n_features+1,).
      Returns :
         (DataFrame) a Dataframe with shape (n_features+1,n_samples). 
    '''
    
    for index, sample in df.iterrows():
        vector = model.infer_vector(doc_words=sample['raw_text'], steps=20)
        dic = {}
        for i in range(len(vector)):
            dic['y_' + str(i)] = vector[i]
        dic['tag'] = sample['tag']
        df_vector = df_vector.append(dic, ignore_index=True)
    df_vector.loc[:, 'y_0':'y_' + str(len(vector) - 1)] = normalize(
            df_vector.loc[:, 'y_0':'y_' + str(len(vector) - 1)],
            norm='l2',
            axis=0)
    return df_vector

# %%
def main(df,
         n_shuffles=10,
         n_splits=10,
         vector_size=100,
         verbose=0):

    matr_accuracy = np.zeros((n_shuffles, n_splits), dtype=float)
    if verbose >= 0:
        print("SEEDs: ", random_seed)

    for i in range(n_shuffles):

        if verbose >= 1:
            print("\n\n_______Shuffle number " + str(i) + "_______\nSEED:" +
                  str(random_seed[i]))
        random.seed(random_seed[i])
        df = df.sample(
            frac=1, random_state=random_seed[i]).reset_index(drop=True)
        if verbose >= 2:
            print("SHUFFLED DATASET: \n")
            print(df.head(3))
            print(df.shape)
        kf = KFold(n_splits=n_splits)
        count = 0
        for train_index, test_index in kf.split(df):
            if verbose >= 1:
                print("_______cross validation round: " + str(count) +
                      "_______")
            if verbose >= 3: print("test indexes: ", test_index)
    
            df_test = df.loc[test_index[0]:test_index[len(test_index) - 1]]
            df_train = df.drop(df.index[test_index])
            if verbose >= 3:
                print("TEST SET: ", df_test)
                print("shape: ", df_test.shape)
                print("TRAIN SET:", df_train.head(10))
                print("shape: ", df_train.shape)

            documents = []
            for index, sample in df_train.iterrows():
                documents.append(
                    TaggedDocument(
                        words=sample['raw_text'],
                        tags=[sample['tag']]))
            if verbose>=3 : print("TAGGED documents: ",documents[0],"\nlen documents: ",len(documents))
            model_D2V = Doc2Vec(
                documents,
                vector_size=vector_size,
                epochs=20,
                min_count=1,
                workers=os.cpu_count())
            #model_D2V.save("model_D2V/sh"+str(count)+"_cv"+str(i))
            
            df_vector = create_vector_dataset(df_train, model_D2V)
            df_test_vector = create_vector_dataset(df_test, model_D2V)
            if verbose >= 2:
                print("TEST SET VECTOR: ", df_test_vector.head(10))
                print("shape: ", df_test_vector.shape)
                print("TRAIN SET:", df_vector.head(10))
                print("shape: ", df_vector.shape)


            clf_svm = svm.SVC(kernel='linear',C=1)
            clf_svm.fit(
                df_vector.loc[:, 'y_0':'y_' + str(vector_size - 1)].values,
                df_vector.loc[:, 'tag'].values)

            predictions = clf_svm.predict(
                df_test_vector.loc[:, 'y_0':'y_' +
                                   str(vector_size - 1)].values)
            tag_test = df_test_vector.loc[:, 'tag'].values
            acc = metrics.accuracy_score(tag_test, predictions)
            if verbose >= 0:
                print("ACCURACY:", acc)
                #print("Precision:",metrics.precision_score(tag_test, predictions))
                #print("Recall:",metrics.recall_score(tag_test, predictions))

            matr_accuracy[i][count] = acc
            count += 1

    return matr_accuracy

# %%
if __name__ == "__main__":
    print(
        "Note: \n* Be sure you are in the same folder contaning the Crystal Ball data set.\n* You might need to install some libraries, here's the list: "
    )
    print(set(sys.modules) & set(globals()))
    # %time matr = main(dataframe,n_shuffles=10,n_splits=10,vector_size=100,verbose=1)
    print(matr.__str__())
    plt.matshow(matr)
    plt.show()
# Out:
# Note:
# * Be sure you are in the same folder contaning the Crystal Ball data set.
# * You might need to install some libraries, here's the list:
# {'sys', 'nltk', 'string', 're', 'regex', 'random', 'os', 'shutil', 'json'}
# SEEDs:  [1234, 232345, 334456, 454567, 567448, 67839, 9822276, 763454, 644543, 3454421]
#
#
# _______Shuffle number 0_______
# SEED:1234
# _______cross validation round: 0_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 1_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 2_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 3_______
# ACCURACY: 0.704225352112676
# _______cross validation round: 4_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 5_______
# ACCURACY: 0.6619718309859155
# _______cross validation round: 6_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 7_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 8_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 9_______
# ACCURACY: 0.8285714285714286
#
#
# _______Shuffle number 1_______
# SEED:232345
# _______cross validation round: 0_______
# ACCURACY: 0.6901408450704225
# _______cross validation round: 1_______
# ACCURACY: 0.6619718309859155
# _______cross validation round: 2_______
# ACCURACY: 0.8169014084507042
# _______cross validation round: 3_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 4_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 5_______
# ACCURACY: 0.8450704225352113
# _______cross validation round: 6_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 7_______
# ACCURACY: 0.704225352112676
# _______cross validation round: 8_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 9_______
# ACCURACY: 0.7857142857142857
#
#
# _______Shuffle number 2_______
# SEED:334456
# _______cross validation round: 0_______
# ACCURACY: 0.8028169014084507
# _______cross validation round: 1_______
# ACCURACY: 0.6901408450704225
# _______cross validation round: 2_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 3_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 4_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 5_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 6_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 7_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 8_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 9_______
# ACCURACY: 0.8571428571428571
#
#
# _______Shuffle number 3_______
# SEED:454567
# _______cross validation round: 0_______
# ACCURACY: 0.8169014084507042
# _______cross validation round: 1_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 2_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 3_______
# ACCURACY: 0.6901408450704225
# _______cross validation round: 4_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 5_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 6_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 7_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 8_______
# ACCURACY: 0.8028169014084507
# _______cross validation round: 9_______
# ACCURACY: 0.7
#
#
# _______Shuffle number 4_______
# SEED:567448
# _______cross validation round: 0_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 1_______
# ACCURACY: 0.8028169014084507
# _______cross validation round: 2_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 3_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 4_______
# ACCURACY: 0.8028169014084507
# _______cross validation round: 5_______
# ACCURACY: 0.704225352112676
# _______cross validation round: 6_______
# ACCURACY: 0.704225352112676
# _______cross validation round: 7_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 8_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 9_______
# ACCURACY: 0.7285714285714285
#
#
# _______Shuffle number 5_______
# SEED:67839
# _______cross validation round: 0_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 1_______
# ACCURACY: 0.704225352112676
# _______cross validation round: 2_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 3_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 4_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 5_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 6_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 7_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 8_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 9_______
# ACCURACY: 0.7571428571428571
#
#
# _______Shuffle number 6_______
# SEED:9822276
# _______cross validation round: 0_______
# ACCURACY: 0.8169014084507042
# _______cross validation round: 1_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 2_______
# ACCURACY: 0.647887323943662
# _______cross validation round: 3_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 4_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 5_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 6_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 7_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 8_______
# ACCURACY: 0.8169014084507042
# _______cross validation round: 9_______
# ACCURACY: 0.7571428571428571
#
#
# _______Shuffle number 7_______
# SEED:763454
# _______cross validation round: 0_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 1_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 2_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 3_______
# ACCURACY: 0.8169014084507042
# _______cross validation round: 4_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 5_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 6_______
# ACCURACY: 0.6619718309859155
# _______cross validation round: 7_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 8_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 9_______
# ACCURACY: 0.7857142857142857
#
#
# _______Shuffle number 8_______
# SEED:644543
# _______cross validation round: 0_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 1_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 2_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 3_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 4_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 5_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 6_______
# ACCURACY: 0.7183098591549296
# _______cross validation round: 7_______
# ACCURACY: 0.676056338028169
# _______cross validation round: 8_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 9_______
# ACCURACY: 0.7857142857142857
#
#
# _______Shuffle number 9_______
# SEED:3454421
# _______cross validation round: 0_______
# ACCURACY: 0.8309859154929577
# _______cross validation round: 1_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 2_______
# ACCURACY: 0.7746478873239436
# _______cross validation round: 3_______
# ACCURACY: 0.6197183098591549
# _______cross validation round: 4_______
# ACCURACY: 0.7605633802816901
# _______cross validation round: 5_______
# ACCURACY: 0.7464788732394366
# _______cross validation round: 6_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 7_______
# ACCURACY: 0.7887323943661971
# _______cross validation round: 8_______
# ACCURACY: 0.7323943661971831
# _______cross validation round: 9_______
# ACCURACY: 0.7285714285714285
# CPU times: user 5h 29min 13s, sys: 4min 36s, total: 5h 33min 49s
# Wall time: 4h 5min 31s
# [[0.67605634 0.76056338 0.74647887 0.70422535 0.78873239 0.66197183
#   0.78873239 0.77464789 0.74647887 0.82857143]
#  [0.69014085 0.66197183 0.81690141 0.73239437 0.74647887 0.84507042
#   0.76056338 0.70422535 0.71830986 0.78571429]
#  [0.8028169  0.69014085 0.73239437 0.71830986 0.73239437 0.73239437
#   0.73239437 0.73239437 0.73239437 0.85714286]
#  [0.81690141 0.74647887 0.76056338 0.69014085 0.78873239 0.74647887
#   0.73239437 0.77464789 0.8028169  0.7       ]
#  [0.67605634 0.8028169  0.67605634 0.71830986 0.8028169  0.70422535
#   0.70422535 0.73239437 0.78873239 0.72857143]
#  [0.78873239 0.70422535 0.77464789 0.71830986 0.74647887 0.71830986
#   0.74647887 0.74647887 0.71830986 0.75714286]
#  [0.81690141 0.67605634 0.64788732 0.76056338 0.74647887 0.76056338
#   0.78873239 0.74647887 0.81690141 0.75714286]
#  [0.71830986 0.77464789 0.77464789 0.81690141 0.78873239 0.77464789
#   0.66197183 0.74647887 0.77464789 0.78571429]
#  [0.71830986 0.76056338 0.77464789 0.67605634 0.73239437 0.74647887
#   0.71830986 0.67605634 0.78873239 0.78571429]
#  [0.83098592 0.77464789 0.77464789 0.61971831 0.76056338 0.74647887
#   0.73239437 0.78873239 0.73239437 0.72857143]]

# %%
plt.matshow(matr, vmin=0.6, vmax=0.75)

print("mean: ", matr.mean())
print("min: ", matr.min())
print("max: ", matr.max())
matr.mean(1)
# Out:
# mean:  0.7471428571428571
# min:  0.6197183098591549
# max:  0.8571428571428571
# array([0.74764588, 0.74617706, 0.74627767, 0.75591549, 0.73342052,
#        0.74191147, 0.75177062, 0.76167002, 0.73772636, 0.74891348])

# %% [markdown]
# ### The results below has been got by including all the biases in the simple pre-processing which means including all the text of the case law.

# %%
plt.matshow(matr, vmin=0.6, vmax=0.75)

print("mean: ", matr.mean())
print("min: ", matr.min())
print("max: ", matr.max())
matr.mean(1)
# Out:
# mean:  0.7751790744466802
# min:  0.6619718309859155
# max:  0.8732394366197183
# array([0.78710262, 0.77016097, 0.76875252, 0.77002012, 0.7643662 ,
#        0.77575453, 0.76018109, 0.77995976, 0.79273642, 0.78275654])
